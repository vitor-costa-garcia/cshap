# %% [markdown]
# # Wind Direction Prediction
#
# Aplicação: Previsão de Vetor de Vento
# Dataset: [Kaggle Jena Climate Dataset](https://www.kaggle.com/datasets/mnassrib/jena-climate?resource=download)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
import cycshap

np.random.seed(42)
