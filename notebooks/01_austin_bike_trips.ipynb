# %% [markdown]
# # Austin Bike Share Trips
# Aplicação: Previsão do momento de aluguel
# Dataset: [Kaggle Austin Bike Share](https://www.kaggle.com/datasets/jboysen/austin-bike?select=austin_bikeshare_trips.csv)

# %%
##
